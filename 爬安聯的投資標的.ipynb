# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import re
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import Select

import requests

# %%
url='https://product.allianz.com.tw/investment/VXD/target-information'

options = Options()
options.headless = False
driverPath = r'C:\Users\user\Documents\GitHub\allianzCrawl\geckodriver.exe'
driver = webdriver.Firefox(options=options, executable_path=driverPath)
#driver = webdriver.Firefox(executable_path=driverPath)

#headless模式
#options = webdriver.ChromeOptions()
#options.add_argument('--headless')
#driver = webdriver.Chrome(options=options, executable_path='chromedriver.exe')
#driver = webdriver.Chrome(executable_path='chromedriver.exe')

driver.set_page_load_timeout(60)
driver.get(url)

# %%
#自己滑到最後

# %%
target_name=[]
target_url=[]
url_pre = 'https://product.allianz.com.tw'
htmltext = driver.page_source

soup=BeautifulSoup(htmltext,"html.parser")

#搜尋所有含quiz的連結
links = soup.find_all('a',{'href':re.compile('VXD')})

for link in links:

        #取得href屬性前先檢查是否存在
    if 'href' in link.attrs:
        href = link['href']

        target_name.append(link.text)
        target_url.append(url_pre + href)
    else:
        href = None

#檢查抓到幾筆資料
print(len(target_url))
# Out:
# 846

# %%
target_url[0]
# Out:
# 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0010/FUND_INFORMATION'

# %%
url = target_url[0]
driver.get(url)

htmltext = driver.page_source

soup=BeautifulSoup(htmltext,"html.parser")
print(soup)
# Out:
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <title>商品專區 | 安聯人壽</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="完整多樣的投資標的及彈性繳費與保障，提供整合性的解決方案以掌握世界財經脈動，真正滿足客戶不同階段的人生規劃。" name="description"/>
# <meta content="Allianz,ETF,全權委託,安聯人壽,投資型,保障,保險,基金,壽險,變額年金" name="keywords"/>
# <link href="assets/images/allianz_fav_icon/favicon - 16px.png" rel="icon" size="16x16" type="image/png"/>
# <link href="assets/images/allianz_fav_icon/favicon - 32px.png" rel="icon" size="32x32" type="image/png"/>
# <link href="assets/images/allianz_fav_icon/favicon - 64px.png" rel="icon" size="64x64" type="image/png"/>
# <link href="assets/images/allianz_fav_icon/favicon - 128px.png" rel="icon" size="128x128" type="image/png"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://robot.allianz.com.tw/api/ai" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-21926965-6"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#       gtag('js', new Date());
#     </script>
# <script src="assets/js/chatbot.js"></script>
# <link href="styles.873daa2589248c583a8b.css" rel="stylesheet"/><style></style><style>.content-wrapper[_ngcontent-toe-c1]{padding-top:80px}#go-to-top[_ngcontent-toe-c1]{display:inline-flex;position:fixed;bottom:45px;right:140px;width:50px;height:50px;background:rgba(255,255,255,.5);align-items:center;justify-content:center;border:1px solid #414141;border-radius:25px;opacity:0;transition:opacity .5s;z-index:1;cursor:pointer}#go-to-top.fade[_ngcontent-toe-c1]{opacity:1;z-index:10}.up-arrow[_ngcontent-toe-c1]{display:inline-block;border:solid #414141;border-width:0 4px 4px 0;padding:6px;transform:translate(0,20%) rotate(-135deg)}@media screen and (max-width:1199px){.content-wrapper[_ngcontent-toe-c1]{padding-top:58px}.content-wrapper.submenuActive[_ngcontent-toe-c1]{padding-top:59px}}</style><style>.c-message[_ngcontent-toe-c2]{background-color:#fff;border:1px solid;border-radius:4px;box-sizing:border-box;box-shadow:0 2px 4px rgba(65,65,65,.5);display:block;top:80px;margin-top:16px}.c-message--info[_ngcontent-toe-c2]{border-color:#006192;padding:0}.c-message--mobile-float[_ngcontent-toe-c2]{margin:16px 8px}.c-message__content[_ngcontent-toe-c2]{display:flex;flex-wrap:wrap;margin:23px}.c-message__item-icon[_ngcontent-toe-c2]{font-size:24px;height:24px;width:24px;margin-right:16px}.c-message--info[_ngcontent-toe-c2]   .c-message__item-icon[_ngcontent-toe-c2]{color:#006192}em.c-icon.c-message__item-icon[_ngcontent-toe-c2]{font-size:24px;min-height:inherit}.c-copy[_ngcontent-toe-c2], .c-promotional-element__text-small[_ngcontent-toe-c2]{font-size:16px;line-height:24px;letter-spacing:0;margin:0 0 30px}.c-message__content[_ngcontent-toe-c2]   .c-copy[_ngcontent-toe-c2], .c-message__content[_ngcontent-toe-c2]   .c-promotional-element__text-small[_ngcontent-toe-c2]{align-self:flex-end;flex:1;display:inline;margin:0;line-height:24px;-webkit-hyphens:auto;-ms-hyphens:auto;hyphens:auto;word-wrap:break-word}.c-message__icon-close[_ngcontent-toe-c2]{display:inline-block;margin-top:-8px;margin-right:-8px;margin-left:8px;height:16px;width:16px;font-size:16px;cursor:pointer}em.c-icon.c-icon--close[_ngcontent-toe-c2]{font-size:16px;min-height:inherit}@media screen and (max-width:1199px){.c-message[_ngcontent-toe-c2]{top:58px}.noHeader[_ngcontent-toe-c2]{top:0}}@media (max-width:991px){.c-message--mobile-float[_ngcontent-toe-c2]{z-index:6000;position:fixed;bottom:8px;left:8px;right:8px;background:#fff;width:auto;margin:0}.c-message__content[_ngcontent-toe-c2]{display:block;margin:31px;position:relative}.c-message__icon-close[_ngcontent-toe-c2]{position:absolute;margin:0;right:-16px;top:-16px}.c-message[_ngcontent-toe-c2]{top:auto}}</style><style>.u-container[_ngcontent-toe-c3]{max-width:1440px;margin:0 auto}.c-header-spacer[_ngcontent-toe-c3]{position:fixed;top:0;right:0;left:0}@media (min-width:992px){.c-header[_ngcontent-toe-c3]   .c-navigation--extended[_ngcontent-toe-c3]{display:inherit}}.c-header[_ngcontent-toe-c3]   .c-flyout__layout[_ngcontent-toe-c3]{box-shadow:0 8px 20px rgba(65,65,65,.35)}@media (max-width:1199px){.c-header-spacer[_ngcontent-toe-c3]{height:58px;z-index:15}.c-header[_ngcontent-toe-c3]   .c-navigation--extended[_ngcontent-toe-c3]{display:none}.c-header[_ngcontent-toe-c3]   .c-navigation--compact[_ngcontent-toe-c3]{display:block}.c-header[_ngcontent-toe-c3]   .c-flyout__content[_ngcontent-toe-c3]   .c-navigation__accordion[_ngcontent-toe-c3]{display:inherit}}.c-header[_ngcontent-toe-c3]   .mod-user-menu[_ngcontent-toe-c3]{padding-right:inherit}@media (min-width:1200px){.c-header[_ngcontent-toe-c3]   .mod-user-menu[_ngcontent-toe-c3]{display:none}}.c-header[_ngcontent-toe-c3]   .mod-user-menu[_ngcontent-toe-c3]   .c-flyout__layout[_ngcontent-toe-c3]{background-color:#fff;padding:2rem 2.5rem}.c-header[_ngcontent-toe-c3]   .mod-user-menu[_ngcontent-toe-c3]   .c-button[_ngcontent-toe-c3]{min-height:50px}.c-header[_ngcontent-toe-c3]   .menu-open[_ngcontent-toe-c3]{height:100%!important}.c-header[_ngcontent-toe-c3]   .c-mobilebar[_ ...
# <body>
# <app-root _nghost-toe-c0="" ng-version="8.2.14"><app-layout _ngcontent-toe-c0="" _nghost-toe-c1=""><!-- --><app-cookie-statement _ngcontent-toe-c1="" _nghost-toe-c2=""><div _ngcontent-toe-c2="" class="om-cookie-disclaimer"><div _ngcontent-toe-c2="" class="experience-fragment-page xfpage page basicpage"><div _ngcontent-toe-c2="" class="aem-Grid aem-Grid--12 aem-Grid--default--12"><div _ngcontent-toe-c2="" class="cookie-disclaimer aem-GridColumn aem-GridColumn--default--12"><div _ngcontent-toe-c2="" class="cookie-hairline"><div _ngcontent-toe-c2="" aria-live="polite" class="c-message c-message--info c-message--mobile-float js-close"><div _ngcontent-toe-c2="" class="c-message__content"><em _ngcontent-toe-c2="" aria-hidden="true" class="c-message__item-icon c-icon c-icon--info-circle"></em><p _ngcontent-toe-c2="" class="c-copy"><span _ngcontent-toe-c2="" class="u-highlighted"> 為提供您最佳個人化且即時的服務，本網站透過使用Cookies記錄與存取您的瀏覽使用訊息。 </span> 當您繼續瀏覽(使用)本網站，即表示您同意Cookies技術支援。了解更多資訊請參閱 <a _ngcontent-toe-c2="" class="c-message__link c-link c-link--block" href="https://www.allianz.com.tw/zh-tw/statement/" rel="noopener noreferrer"><span _ngcontent-toe-c2="" aria-hidden="true" class="c-link__icon c-icon c-icon--arrow-right"></span> 隱私權保護聲明。 </a></p><em _ngcontent-toe-c2="" aria-hidden="true" class="c-message__icon-close c-icon c-icon--close js-close-button"></em></div></div></div></div></div></div></div></app-cookie-statement><!-- --><app-header _ngcontent-toe-c1="" _nghost-toe-c3=""><div _ngcontent-toe-c3="" class="c-header-spacer"><header _ngcontent-toe-c3="" class="c-header" id="Header"><div _ngcontent-toe-c3="" class="c-three-level-navigation"><div _ngcontent-toe-c3="" class="c-navigation"><div _ngcontent-toe-c3="" class="c-navigation--extended"><div _ngcontent-toe-c3="" class="u-container"><div _ngcontent-toe-c3="" class="c-navigation__bar c-header__wrapper"><a _ngcontent-toe-c3="" class="c-header__logo" href="https://www.allianz.com.tw/" rel="noopener noreferrer"><img _ngcontent-toe-c3="" alt="Allianz Logo" id="Allianz-Logo" src="./assets/images/allianz-logo.png"/></a><div _ngcontent-toe-c3="" class="c-main-navbar d-flex align-items-center"><ul _ngcontent-toe-c3="" class="c-main-navbar__list mr-auto" role="menu"><li _ngcontent-toe-c3="" class="c-main-navbar__item" role="menuitem"><a _ngcontent-toe-c3="" class="c-main-navbar__link" href="/" rel="noopener noreferrer" routerlink="/" routerlinkactive="active"><span _ngcontent-toe-c3="" class="c-main-navbar__title">首頁</span></a></li><li _ngcontent-toe-c3="" class="c-main-navbar__item" role="menuitem"><a _ngcontent-toe-c3="" class="c-main-navbar__link" href="/protection" rel="noopener noreferrer" routerlink="protection" routerlinkactive="active"><span _ngcontent-toe-c3="" class="c-main-navbar__title">保障型商品</span></a></li><li _ngcontent-toe-c3="" class="c-main-navbar__item" role="menuitem"><a _ngcontent-toe-c3="" class="c-main-navbar__link active" href="/investment" rel="noopener noreferrer" routerlink="investment" routerlinkactive="active"><span _ngcontent-toe-c3="" class="c-main-navbar__title">投資型商品</span></a></li><li _ngcontent-toe-c3="" class="c-main-navbar__item" role="menuitem"><a _ngcontent-toe-c3="" class="c-main-navbar__link" href="/target" rel="noopener noreferrer" routerlink="target" routerlinkactive="active"><span _ngcontent-toe-c3="" class="c-main-navbar__title">標的專區</span></a></li><li _ngcontent-toe-c3="" class="c-main-navbar__item" role="menuitem"><a _ngcontent-toe-c3="" class="c-main-navbar__link" href="/news" rel="noopener noreferrer" routerlink="news" routerlinkactive="active"><span _ngcontent-toe-c3="" class="c-main-navbar__title">最新消息</span></a></li><li _ngcontent-toe-c3="" class="c-main-navbar__item" role="menuitem"><a _ngcontent-toe-c3="" class="c-main-navbar__link" href="/collection" rel="noopener noreferrer" routerlink="collection" routerlinkactive="active"><span _ngcontent-toe-c3="" class="c-main-navbar__title c-main-navbar__collect"><span _ngcontent-toe-c3="" class="heart">< ...
# <script src="runtime-es2015.f32440c8b8b21f58c081.js" type="module"></script><script defer="" nomodule="" src="runtime-es5.f32440c8b8b21f58c081.js"></script><script defer="" nomodule="" src="polyfills-es5.e5676b4be7952d46c7ef.js"></script><script src="polyfills-es2015.640b16416ed0724c7b8b.js" type="module"></script><script defer="" src="scripts.662db19e5c4435800a56.js"></script><script src="main-es2015.53a8835d16c5dcae34b7.js" type="module"></script><script defer="" nomodule="" src="main-es5.53a8835d16c5dcae34b7.js"></script>
# <div class="aztl-va" id="aztl-va" name="aztl-va"><script async="" src="https://robot.allianz.com.tw/webChat/js/jquery-1.12.0.js" type="text/javascript"></script><script async="" src="https://robot.allianz.com.tw/webChat/js/jquery-1.12.0.js" type="text/javascript"></script></div></body></html>

# %%
# providing url
url = target_url[0]
  
# creating requests object
html = requests.get(url).content
  
# creating soup object
data = BeautifulSoup(html, 'html.parser')
print(data)
'''
# finding parent <ul> tag
parent = data.find("body").find("ul")
  
# finding all <li> tags
text = list(parent.descendants)
  
# printing the content in <li> tag
print(text)
for i in range(2, len(text), 2):
    print(text[i], end=" ")
'''
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>商品專區 | 安聯人壽</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="完整多樣的投資標的及彈性繳費與保障，提供整合性的解決方案以掌握世界財經脈動，真正滿足客戶不同階段的人生規劃。" name="description"/>
# <meta content="Allianz,ETF,全權委託,安聯人壽,投資型,保障,保險,基金,壽險,變額年金" name="keywords"/>
# <link href="assets/images/allianz_fav_icon/favicon - 16px.png" rel="icon" size="16x16" type="image/png"/>
# <link href="assets/images/allianz_fav_icon/favicon - 32px.png" rel="icon" size="32x32" type="image/png"/>
# <link href="assets/images/allianz_fav_icon/favicon - 64px.png" rel="icon" size="64x64" type="image/png"/>
# <link href="assets/images/allianz_fav_icon/favicon - 128px.png" rel="icon" size="128x128" type="image/png"/>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-21926965-6"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#       gtag('js', new Date());
#     </script>
# <script src="assets/js/chatbot.js"></script>
# <link href="styles.873daa2589248c583a8b.css" rel="stylesheet"/></head>
# <body>
# <app-root></app-root>
# <script src="runtime-es2015.f32440c8b8b21f58c081.js" type="module"></script><script defer="" nomodule="" src="runtime-es5.f32440c8b8b21f58c081.js"></script><script defer="" nomodule="" src="polyfills-es5.e5676b4be7952d46c7ef.js"></script><script src="polyfills-es2015.640b16416ed0724c7b8b.js" type="module"></script><script defer="" src="scripts.662db19e5c4435800a56.js"></script><script src="main-es2015.53a8835d16c5dcae34b7.js" type="module"></script><script defer="" nomodule="" src="main-es5.53a8835d16c5dcae34b7.js"></script></body>
# </html>
# '\n# finding parent <ul> tag\nparent = data.find("body").find("ul")\n  \n# finding all <li> tags\ntext = list(parent.descendants)\n  \n# printing the content in <li> tag\nprint(text)\nfor i in range(2, len(text), 2):\n    print(text[i], end=" ")\n'

# %%
#取得測驗的連結
id = 1735
#https://weteach.edu.tw/course/view.php?id=1735
courseurl = 'http://weteach.edu.tw/course/view.php?'
quizname=[]
quizurl=[]
for i in range(9):
    url = courseurl + 'id='+str(id) +'&section='+str(i+1)
    driver.get(url)
    #取得各section原始碼
    htmltext = driver.page_source

    soup=BeautifulSoup(htmltext,"html.parser")
    
    #搜尋所有含quiz的連結
    links = soup.find_all('a',{'href':re.compile('quiz')})
    for link in links:

        #取得href屬性前先檢查是否存在
        if 'href' in link.attrs:
            href = link['href']
            print(link.text)
            print(href)
            quizname.append(link.text)
            quizurl.append(href)
        else:
            href = None
# Out:
# A1段考複習 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=47739
# 神經元 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43599
# 中樞神經與周圍神經 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43600
# 神經傳導途徑-基本題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43601
# 神經傳導途徑-進階題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43602
# 神經傳導途徑-挑戰題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43603
# 內分泌器官認識 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43609
# 內分泌腺-腦垂腺、甲狀腺、副甲狀腺 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43610
# 內分泌腺-血糖調節相關激素 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43611
# 內分泌進階題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43612
# 內分泌腺-性腺 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43613
# 動物的趨性 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43617
# 本能與學習 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43618
# 植物的向性 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43621
# 膨壓造成的改變 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43622
# 內溫與外溫動物 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43626
# 恆溫動物如何調節體溫 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43627
# 人體的呼吸系統 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43630
# 動植物的呼吸 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43631
# 呼吸作用 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43632
# 呼吸運動 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43633
# 呼吸的相關實驗 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43634
# 血糖恆定的激素 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43636
# 血糖恆定的方式 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43637
# 含氮廢物的類型與排泄 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43639
# 人體的泌尿系統 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43640
# 動植物的水分恆定 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43641
# 防止水分散失的方式 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43642

# %%
#從url找id
quizid=[]
for quiz in quizurl:
    k = re.search(r'id=(.*)$', quiz)
    quizid.append(k.group(1))
quizid
# Out:
# ['47739',
#  '43599',
#  '43600',
#  '43601',
#  '43602',
#  '43603',
#  '43609',
#  '43610',
#  '43611',
#  '43612',
#  '43613',
#  '43617',
#  '43618',
#  '43621',
#  '43622',
#  '43626',
#  '43627',
#  '43630',
#  '43631',
#  '43632',
#  '43633',
#  '43634',
#  '43636',
#  '43637',
#  '43639',
#  '43640',
#  '43641',
#  '43642']

# %%
#進入試卷編修網址
                        #https://weteach.edu.tw/course/modedit.php?update=43489&return=0&sr=0
quizurlBase = 'https://weteach.edu.tw/course/modedit.php?update='
n = 0



gradecat = '2067'
#2074:A1 2065:A2 2067:A3 2072:B1 2070:B2  2069:B3
gradepass = 100  #及格分數
attempts = 4    #可測驗次數
grademethod = '1' 
#1:最高分數 2:平均分數 3:第一次作答  4:最後一次作答
for i in quizid:
    quizurl = quizurlBase+str(i)+'&return=1'
    
    driver.get(quizurl)

    #展開全部
    driver.find_element_by_css_selector('.collapseexpand').click()

    #修改及格分數
    element =  driver.find_element_by_id('id_gradepass')
    element.clear()
    element.send_keys(gradepass)

    
    s1 = Select(driver.find_element_by_id('id_gradecat'))
    s1.select_by_value(gradecat)
   
    
    #修改允許作答次數
    #搜尋作答次數的選單並點擊
    element = driver.find_element_by_id('id_attempts')
    element.click()
    element.send_keys(attempts)
    
    
    #修改評分方式
    s1 = Select(driver.find_element_by_id('id_grademethod'))
    s1.select_by_value(grademethod)
    
    
    #解開完成進度的選項
    #還沒有人作答時，此項須註解。等到有人作答後，才可以找到這個element
    driver.find_element_by_id('id_unlockcompletion').click()
      
    #檢查是否勾選「需要及格分數」
    element = driver.find_element_by_id('id_completionpass')
    if element.get_attribute('checked') :
        #如果有勾選，就按一下，讓它取消勾選
        element.click()
        print('checked-->unchecked')
    else:
        print('unchecked')
    
    

    #儲存並顯示
    driver.find_element_by_id('id_submitbutton2').click()
    print('done:' + quizname[n])
    print(quizurl)
    n = n+1
    print(str(n)+"/"+str(len(quizid)))
    print('========')
# Out:
# checked-->unchecked
# done:A1段考複習 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=47739&return=1
# 1/28
# ========
# unchecked
# done:神經元 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43599&return=1
# 2/28
# ========
# unchecked
# done:中樞神經與周圍神經 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43600&return=1
# 3/28
# ========
# unchecked
# done:神經傳導途徑-基本題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43601&return=1
# 4/28
# ========
# unchecked
# done:神經傳導途徑-進階題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43602&return=1
# 5/28
# ========
# unchecked
# done:神經傳導途徑-挑戰題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43603&return=1
# 6/28
# ========
# unchecked
# done:內分泌器官認識 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43609&return=1
# 7/28
# ========
# unchecked
# done:內分泌腺-腦垂腺、甲狀腺、副甲狀腺 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43610&return=1
# 8/28
# ========
# unchecked
# done:內分泌腺-血糖調節相關激素 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43611&return=1
# 9/28
# ========
# unchecked
# done:內分泌進階題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43612&return=1
# 10/28
# ========
# unchecked
# done:內分泌腺-性腺 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43613&return=1
# 11/28
# ========
# unchecked
# done:動物的趨性 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43617&return=1
# 12/28
# ========
# unchecked
# done:本能與學習 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43618&return=1
# 13/28
# ========
# unchecked
# done:植物的向性 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43621&return=1
# 14/28
# ========
# unchecked
# done:膨壓造成的改變 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43622&return=1
# 15/28
# ========
# unchecked
# done:內溫與外溫動物 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43626&return=1
# 16/28
# ========
# unchecked
# done:恆溫動物如何調節體溫 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43627&return=1
# 17/28
# ========
# unchecked
# done:人體的呼吸系統 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43630&return=1
# 18/28
# ========
# unchecked
# done:動植物的呼吸 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43631&return=1
# 19/28
# ========
# unchecked
# done:呼吸作用 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43632&return=1
# 20/28
# ========
# unchecked
# done:呼吸運動 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43633&return=1
# 21/28
# ========
# unchecked
# done:呼吸的相關實驗 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43634&return=1
# 22/28
# ========
# unchecked
# done:血糖恆定的激素 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43636&return=1
# 23/28
# ========
# unchecked
# done:血糖恆定的方式 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43637&return=1
# 24/28
# ========
# unchecked
# done:含氮廢物的類型與排泄 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43639&return=1
# 25/28
# ========
# unchecked
# done:人體的泌尿系統 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43640&return=1
# 26/28
# ========
# unchecked
# done:動植物的水分恆定 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43641&return=1
# 27/28
# ========
# unchecked
# done:防止水分散失的方式 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43642&return=1
# 28/28
# ========

# %% [markdown]
# ## 以下是測試區

# %%
#處理單一連結的測試區

#進入試卷編修網址
url = 'https://weteach.edu.tw/course/modedit.php?update=43593'
driver.get(url)

#element = WebDriverWait(driver,3).until(expected_conditions.presence_of_element_located((By.ID,'id_gradepass')))
#element = driver.find_element_by_name('gradepass')

#展開全部
driver.find_element_by_css_selector('.collapseexpand').click()

#修改及格分數
element =  driver.find_element_by_id('id_gradepass')
element.clear()
element.send_keys('100')

#修改允許作答次數
#搜尋作答次數的選單並點擊
element = driver.find_element_by_id('id_attempts')
element.click()
element.send_keys('7')

#for option in driver.find_elements_by_tag_name('option'):
    #if option.text == '3':
    #    option.click()

grademethod = '2'
#修改評分方式
s1 = Select(driver.find_element_by_id('id_grademethod'))
s1.select_by_value(grademethod)

#element = driver.find_element_by_id('id_grademethod')
#element.click()
#element.send_keys( grademethod )

#解開完成進度的選項
driver.find_element_by_id('id_unlockcompletion').click()


#儲存並顯示
driver.find_element_by_id('id_submitbutton2').click()
print('done')
#element = driver.find_element_by_xpath('//*[@id="id_gradepass"]')


#finally:
    #driver.quit()

# %%
#進入試卷編修網址
url = 'https://weteach.edu.tw/course/modedit.php?update=43593'
driver.get(url)

#element = WebDriverWait(driver,3).until(expected_conditions.presence_of_element_located((By.ID,'id_gradepass')))
#element = driver.find_element_by_name('gradepass')

#展開全部
driver.find_element_by_css_selector('.collapseexpand').click()

#解開完成進度的選項
driver.find_element_by_id('id_unlockcompletion').click()


#檢查是否勾選「需要及格分數」
element = driver.find_element_by_id('id_completionpass')
if element.get_attribute('checked') :
    #如果有勾選，就按一下，讓它取消勾選
    element.click()
    print('checked-->unchecked')
else:
    print('unchecked')

# %%
for i in range(2,7):
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
