# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import re
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import Select

# %%
url='https://product.allianz.com.tw/investment/VXD/target-information'

options = Options()
options.headless = False
driverPath = r'C:\Users\user\Documents\GitHub\allianzCrawl\geckodriver.exe'
driver = webdriver.Firefox(options=options, executable_path=driverPath)
#driver = webdriver.Firefox(executable_path=driverPath)

#headless模式
#options = webdriver.ChromeOptions()
#options.add_argument('--headless')
#driver = webdriver.Chrome(options=options, executable_path='chromedriver.exe')
#driver = webdriver.Chrome(executable_path='chromedriver.exe')

driver.set_page_load_timeout(60)
driver.get(url)

# %%
target_name=[]
target_url=[]
url_pre = 'https://product.allianz.com.tw'
htmltext = driver.page_source

soup=BeautifulSoup(htmltext,"html.parser")

#搜尋所有含quiz的連結
links = soup.find_all('a',{'href':re.compile('VXD')})

for link in links:

        #取得href屬性前先檢查是否存在
    if 'href' in link.attrs:
        href = link['href']

        target_name.append(link.text)
        target_url.append(url_pre + href)
    else:
        href = None

print(target_url)
# Out:
# ['https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0010/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0020/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0030/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0040/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0050/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0060/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0070/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0080/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0090/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0130/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0140/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0160/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0170/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0180/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0200/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0210/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0310/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0330/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0440/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDBO0470/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0010/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0030/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0050/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0080/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0110/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0150/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0160/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ0180/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1190/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1200/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1250/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1270/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1280/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1290/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1300/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1310/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1330/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1340/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDEQ1350/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDMY0020/FUND_INFORMATION', 'https://product.allianz.com.tw/investment/VXD/target-information/AUDRT0010/parking', 'https://product.allianz.com.tw/investment/VXD/target-information/EURBO0040/FUND_INFORMATION', 'https://product.a ...

# %%
#取得測驗的連結
id = 1735
#https://weteach.edu.tw/course/view.php?id=1735
courseurl = 'http://weteach.edu.tw/course/view.php?'
quizname=[]
quizurl=[]
for i in range(9):
    url = courseurl + 'id='+str(id) +'&section='+str(i+1)
    driver.get(url)
    #取得各section原始碼
    htmltext = driver.page_source

    soup=BeautifulSoup(htmltext,"html.parser")
    
    #搜尋所有含quiz的連結
    links = soup.find_all('a',{'href':re.compile('quiz')})
    for link in links:

        #取得href屬性前先檢查是否存在
        if 'href' in link.attrs:
            href = link['href']
            print(link.text)
            print(href)
            quizname.append(link.text)
            quizurl.append(href)
        else:
            href = None
# Out:
# A1段考複習 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=47739
# 神經元 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43599
# 中樞神經與周圍神經 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43600
# 神經傳導途徑-基本題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43601
# 神經傳導途徑-進階題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43602
# 神經傳導途徑-挑戰題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43603
# 內分泌器官認識 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43609
# 內分泌腺-腦垂腺、甲狀腺、副甲狀腺 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43610
# 內分泌腺-血糖調節相關激素 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43611
# 內分泌進階題 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43612
# 內分泌腺-性腺 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43613
# 動物的趨性 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43617
# 本能與學習 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43618
# 植物的向性 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43621
# 膨壓造成的改變 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43622
# 內溫與外溫動物 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43626
# 恆溫動物如何調節體溫 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43627
# 人體的呼吸系統 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43630
# 動植物的呼吸 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43631
# 呼吸作用 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43632
# 呼吸運動 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43633
# 呼吸的相關實驗 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43634
# 血糖恆定的激素 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43636
# 血糖恆定的方式 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43637
# 含氮廢物的類型與排泄 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43639
# 人體的泌尿系統 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43640
# 動植物的水分恆定 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43641
# 防止水分散失的方式 測驗卷
# https://weteach.edu.tw/mod/quiz/view.php?id=43642

# %%
#從url找id
quizid=[]
for quiz in quizurl:
    k = re.search(r'id=(.*)$', quiz)
    quizid.append(k.group(1))
quizid
# Out:
# ['47739',
#  '43599',
#  '43600',
#  '43601',
#  '43602',
#  '43603',
#  '43609',
#  '43610',
#  '43611',
#  '43612',
#  '43613',
#  '43617',
#  '43618',
#  '43621',
#  '43622',
#  '43626',
#  '43627',
#  '43630',
#  '43631',
#  '43632',
#  '43633',
#  '43634',
#  '43636',
#  '43637',
#  '43639',
#  '43640',
#  '43641',
#  '43642']

# %%
#進入試卷編修網址
                        #https://weteach.edu.tw/course/modedit.php?update=43489&return=0&sr=0
quizurlBase = 'https://weteach.edu.tw/course/modedit.php?update='
n = 0



gradecat = '2067'
#2074:A1 2065:A2 2067:A3 2072:B1 2070:B2  2069:B3
gradepass = 100  #及格分數
attempts = 4    #可測驗次數
grademethod = '1' 
#1:最高分數 2:平均分數 3:第一次作答  4:最後一次作答
for i in quizid:
    quizurl = quizurlBase+str(i)+'&return=1'
    
    driver.get(quizurl)

    #展開全部
    driver.find_element_by_css_selector('.collapseexpand').click()

    #修改及格分數
    element =  driver.find_element_by_id('id_gradepass')
    element.clear()
    element.send_keys(gradepass)

    
    s1 = Select(driver.find_element_by_id('id_gradecat'))
    s1.select_by_value(gradecat)
   
    
    #修改允許作答次數
    #搜尋作答次數的選單並點擊
    element = driver.find_element_by_id('id_attempts')
    element.click()
    element.send_keys(attempts)
    
    
    #修改評分方式
    s1 = Select(driver.find_element_by_id('id_grademethod'))
    s1.select_by_value(grademethod)
    
    
    #解開完成進度的選項
    #還沒有人作答時，此項須註解。等到有人作答後，才可以找到這個element
    driver.find_element_by_id('id_unlockcompletion').click()
      
    #檢查是否勾選「需要及格分數」
    element = driver.find_element_by_id('id_completionpass')
    if element.get_attribute('checked') :
        #如果有勾選，就按一下，讓它取消勾選
        element.click()
        print('checked-->unchecked')
    else:
        print('unchecked')
    
    

    #儲存並顯示
    driver.find_element_by_id('id_submitbutton2').click()
    print('done:' + quizname[n])
    print(quizurl)
    n = n+1
    print(str(n)+"/"+str(len(quizid)))
    print('========')
# Out:
# checked-->unchecked
# done:A1段考複習 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=47739&return=1
# 1/28
# ========
# unchecked
# done:神經元 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43599&return=1
# 2/28
# ========
# unchecked
# done:中樞神經與周圍神經 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43600&return=1
# 3/28
# ========
# unchecked
# done:神經傳導途徑-基本題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43601&return=1
# 4/28
# ========
# unchecked
# done:神經傳導途徑-進階題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43602&return=1
# 5/28
# ========
# unchecked
# done:神經傳導途徑-挑戰題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43603&return=1
# 6/28
# ========
# unchecked
# done:內分泌器官認識 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43609&return=1
# 7/28
# ========
# unchecked
# done:內分泌腺-腦垂腺、甲狀腺、副甲狀腺 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43610&return=1
# 8/28
# ========
# unchecked
# done:內分泌腺-血糖調節相關激素 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43611&return=1
# 9/28
# ========
# unchecked
# done:內分泌進階題 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43612&return=1
# 10/28
# ========
# unchecked
# done:內分泌腺-性腺 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43613&return=1
# 11/28
# ========
# unchecked
# done:動物的趨性 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43617&return=1
# 12/28
# ========
# unchecked
# done:本能與學習 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43618&return=1
# 13/28
# ========
# unchecked
# done:植物的向性 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43621&return=1
# 14/28
# ========
# unchecked
# done:膨壓造成的改變 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43622&return=1
# 15/28
# ========
# unchecked
# done:內溫與外溫動物 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43626&return=1
# 16/28
# ========
# unchecked
# done:恆溫動物如何調節體溫 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43627&return=1
# 17/28
# ========
# unchecked
# done:人體的呼吸系統 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43630&return=1
# 18/28
# ========
# unchecked
# done:動植物的呼吸 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43631&return=1
# 19/28
# ========
# unchecked
# done:呼吸作用 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43632&return=1
# 20/28
# ========
# unchecked
# done:呼吸運動 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43633&return=1
# 21/28
# ========
# unchecked
# done:呼吸的相關實驗 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43634&return=1
# 22/28
# ========
# unchecked
# done:血糖恆定的激素 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43636&return=1
# 23/28
# ========
# unchecked
# done:血糖恆定的方式 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43637&return=1
# 24/28
# ========
# unchecked
# done:含氮廢物的類型與排泄 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43639&return=1
# 25/28
# ========
# unchecked
# done:人體的泌尿系統 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43640&return=1
# 26/28
# ========
# unchecked
# done:動植物的水分恆定 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43641&return=1
# 27/28
# ========
# unchecked
# done:防止水分散失的方式 測驗卷
# https://weteach.edu.tw/course/modedit.php?update=43642&return=1
# 28/28
# ========

# %% [markdown]
# ## 以下是測試區

# %%
#處理單一連結的測試區

#進入試卷編修網址
url = 'https://weteach.edu.tw/course/modedit.php?update=43593'
driver.get(url)

#element = WebDriverWait(driver,3).until(expected_conditions.presence_of_element_located((By.ID,'id_gradepass')))
#element = driver.find_element_by_name('gradepass')

#展開全部
driver.find_element_by_css_selector('.collapseexpand').click()

#修改及格分數
element =  driver.find_element_by_id('id_gradepass')
element.clear()
element.send_keys('100')

#修改允許作答次數
#搜尋作答次數的選單並點擊
element = driver.find_element_by_id('id_attempts')
element.click()
element.send_keys('7')

#for option in driver.find_elements_by_tag_name('option'):
    #if option.text == '3':
    #    option.click()

grademethod = '2'
#修改評分方式
s1 = Select(driver.find_element_by_id('id_grademethod'))
s1.select_by_value(grademethod)

#element = driver.find_element_by_id('id_grademethod')
#element.click()
#element.send_keys( grademethod )

#解開完成進度的選項
driver.find_element_by_id('id_unlockcompletion').click()


#儲存並顯示
driver.find_element_by_id('id_submitbutton2').click()
print('done')
#element = driver.find_element_by_xpath('//*[@id="id_gradepass"]')


#finally:
    #driver.quit()

# %%
#進入試卷編修網址
url = 'https://weteach.edu.tw/course/modedit.php?update=43593'
driver.get(url)

#element = WebDriverWait(driver,3).until(expected_conditions.presence_of_element_located((By.ID,'id_gradepass')))
#element = driver.find_element_by_name('gradepass')

#展開全部
driver.find_element_by_css_selector('.collapseexpand').click()

#解開完成進度的選項
driver.find_element_by_id('id_unlockcompletion').click()


#檢查是否勾選「需要及格分數」
element = driver.find_element_by_id('id_completionpass')
if element.get_attribute('checked') :
    #如果有勾選，就按一下，讓它取消勾選
    element.click()
    print('checked-->unchecked')
else:
    print('unchecked')

# %%
for i in range(2,7):
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
